# %% [markdown]
# ## Tool - REBEL: Relation Extraction By End-to-end Language generation
# ---

# %% [markdown]
# ### Load and standardize the data

# %%
import pandas as pd
import ast

# input file
nel_result = '../../data/results/spacy_entity_linker/FAA_DataModel_20240104104402.csv'

# load output from the tool to be evaluated
data = pd.read_csv(nel_result)

# %%
# rename columns
data.rename(columns={"c5": "id", "c119": "sample", "c119_entity_linking":"entity_linking"}, inplace=True)

# Convert the string representation of a list of dictionaries to actual list of dictionaries
data['entity_linking'] = data['entity_linking'].apply(ast.literal_eval)

# explode the entity_linking column
data = data.explode('entity_linking').reset_index(drop=True)

# %%
# Convert the dictionary column to a DataFrame
attributes_df = data['entity_linking'].apply(pd.Series)

# change the column type to object
attributes_df['indentifier'] = attributes_df['indentifier'].astype('Int64')

attributes_df.drop(columns=[0], inplace=True)
attributes_df
# Out:
#        indentifier                           label  \
# 0          8015236           William Matthew Prior
# 1          6588629         Toledo Airport (Brazil)
# 2          4698432                        Airborne
# 3          3951828                          agency
# 4          6588629         Toledo Airport (Brazil)
# ...            ...                             ...
# 16891      5421066                     Experienced
# 16892         6203               Avogadro constant
# 16893      5727902                           circa
# 16894      1431062  Castellón-Costa Azahar Airport
# 16895      4385298     Tuscaloosa National Airport
#
#                                              description
# 0                                       American painter
# 1                                                   None
# 2                       controversial dietary supplement
# 3                 capacity of an agent to act in a world
# 4                                                   None
# ...                                                  ...
# 16891                                         live album
# 16892  fundamental physical constant (symbols: L,Nᴀ) ...
# 16893  approximately – should be used with qualifier ...
# 16894                                            airport
# 16895  airport in Tuscaloosa County, United States of...
#
# [16896 rows x 3 columns]

# %%
# Concatenate with the original DataFrame (minus the dictionary column)
data = pd.concat([data.drop('entity_linking', axis=1), attributes_df], axis=1)

data
# Out:
#                     id                                             sample  \
# 0      19750315005389A  TAILWHEEL COCKED RIGHT PRIOR TO TKOF.         ...
# 1      19750419011349A  TOW PLANE BECAME AIRBORNE THEN SETTLED.STUDENT...
# 2      19750419011349A  TOW PLANE BECAME AIRBORNE THEN SETTLED.STUDENT...
# 3      19750419011349A  TOW PLANE BECAME AIRBORNE THEN SETTLED.STUDENT...
# 4      19750419011349A  TOW PLANE BECAME AIRBORNE THEN SETTLED.STUDENT...
# ...                ...                                                ...
# 16891  20080404840559A  (-23) THE AIRCRAFT EXPERIENCED SEVERE TURBULAN...
# 16892  20080404840559A  (-23) THE AIRCRAFT EXPERIENCED SEVERE TURBULAN...
# 16893  20080404840559A  (-23) THE AIRCRAFT EXPERIENCED SEVERE TURBULAN...
# 16894  20080404840559A  (-23) THE AIRCRAFT EXPERIENCED SEVERE TURBULAN...
# 16895  20080404840559A  (-23) THE AIRCRAFT EXPERIENCED SEVERE TURBULAN...
#
#        indentifier                           label  \
# 0          8015236           William Matthew Prior
# 1          6588629         Toledo Airport (Brazil)
# 2          4698432                        Airborne
# 3          3951828                          agency
# 4          6588629         Toledo Airport (Brazil)
# ...            ...                             ...
# 16891      5421066                     Experienced
# 16892         6203               Avogadro constant
# 16893      5727902                           circa
# 16894      1431062  Castellón-Costa Azahar Airport
# 16895      4385298     Tuscaloosa National Airport
#
#                                              description
# 0                                       American painter
# 1                                                   None
# 2                       controversial dietary supplement
# 3                 capacity of an agent to act in a world
# 4                                                   None
# ...                                                  ...
# 16891                                         live album
# 16892  fundamental physical constant (symbols: L,Nᴀ) ...
# 16893  approximately – should be used with qualifier ...
# 16894                                            airport
# 16895  airport in Tuscaloosa County, United States of...
#
# [16896 rows x 5 columns]

# %% [markdown]
# save the processed tool output to a file

# %%
data.to_csv('../../tool_results/spacy_entitylinker.csv', index=False)

# %% [markdown]
# ## Gold standard NEL data

# %% [markdown]
# ### Load the processed gold standard data

# %%
import pandas as pd

gold_standard_path = '../../gold_standard/processed/nel.csv'

# load output from the tool to be evaluated
data = pd.read_csv(gold_standard_path)

data
# Out:
#                   id                                             sample  \
# 0    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 1    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 2    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 3    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 4    19800217031649I  AFTER TAKEOFF, ENGINE QUIT. WING FUEL TANK SUM...
# ..               ...                                                ...
# 496  19870523018729A  CANOPY CAME OPEN ON CLIMBOUT CAUSING AN UNCONT...
# 497  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 498  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 499  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 500  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
#
#              entity        qid
# 0              ACFT     Q11436
# 1             DITCH   Q2048319
# 2              TREE     Q10884
# 3      LOST CONTROL  Q29017603
# 4           TAKEOFF    Q854248
# ..              ...        ...
# 496     PILOT ERROR   Q3057459
# 497           PILOT   Q2095549
# 498  OIL FILLER CAP        NaN
# 499             OIL     Q42962
# 500          ENGINE     Q44167
#
# [501 rows x 4 columns]

# %%
data[data.id=='19990213001379A']['sample'][0:1].to_string(index=False)
# Out:
# 'ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CONT...'
