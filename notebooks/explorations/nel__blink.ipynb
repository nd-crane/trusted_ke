# %% [markdown]
# ## Tool - BLINK
# ---

# %%
import os, ast
import pandas as pd

nlp_task = 'nel'
tool_name = 'blink'
tool_result_path = '../../data/results/blink/blink_results.csv'
gs_samples_path = '../../gold_standard/processed/samples.csv'
output_dir = '../../tool_results/'

# %% [markdown]
# ### Load and standardize the data

# %%
# load output from the tool to be evaluated
data = pd.read_csv(tool_result_path)
data
# Out:
#       doc_idx  sent_idx                                  original_sentence  \
# 0           0         0  TAILWHEEL COCKED RIGHT PRIOR TO TKOF.         ...
# 1           2         1  2ND ILS APCH,ACFT'S G/S INOP.LOM TUNED TO WRON...
# 2           7         0  MTNS OBSCURED.FLT TO CK VOR REC REPTD INOP PRI...
# 3          10         1  LEFT ENG OIL SUPPLY EXHAUSTED.GEAR-UP LDG IN M...
# 4          22         0  APRX 1/2 CUPFULL FLUID UNDER R BRAKE PRIOR TO ...
# ...       ...       ...                                                ...
# 1159     2742         0  ON 7/22/08 AT 1249 MST, CESSNA T182T, N562GK, ...
# 1160     2743         0  (-23) A/C RELOCATED TO NEW HANGAR TO CHECK SIZ...
# 1161     2744         0  (-23) ON 2/23/08 @ APPROXIMATELY 2130 DURING T...
# 1162     2745         0  (-23) PILOT TOOK OFF FOR LEESBURG AIRPORT AND ...
# 1163     2746         1  (-23) OWNER FORGOT TO FASTEN THE LOWER LEFT 4 ...
#
#                                                   input     mention  \
# 0                 tailwheel cocked right prior to tkof.   tailwheel
# 1                              lom tuned to wrong freq.         lom
# 2                                        mtns obscured.        mtns
# 3                        gear-up ldg in mesquite brush.    mesquite
# 4     aprx 1/2 cupfull fluid under r brake prior to ...        aprx
# ...                                                 ...         ...
# 1159  on 7/22/08 at 1249 mst, cessna t182t, n562gk, ...         mst
# 1160  (-23) a/c relocated to new hangar to check siz...  new hangar
# 1161  (-23) on 2/23/08 @ approximately 2130 during t...        airc
# 1162  (-23) pilot took off for leesburg airport and ...    leesburg
# 1163           cowling came loose after takeoff, block.     cowling
#
#                                          bi_pred_entity    bi_qid  \
# 0                                              Flywheel   Q183576
# 1                                           Lom, Norway   Q488395
# 2                                                  KCNS  Q6327147
# 3                                              Mesquite  Q3315767
# 4                           Audi Performance and Racing  Q4819705
# ...                                                 ...       ...
# 1159                        South African Standard Time   Q770321
# 1160  American Airways Hangar and Administration Bui...  Q4742968
# 1161                          Air Force Reserve Command   Q407191
# 1162                                 Leesburg, Virginia  Q1012089
# 1163                                            Cowling  Q1138219
#
#                                                 bi_desc  \
# 0      A flywheel is a mechanical device specificall...
# 1      Lom is a municipality in Oppland county, Norw...
# 2      KCNS, virtual channel 38 (UHF digital channel...
# 3      Mesquite is a common name for several plants ...
# 4      APR LLC is an American automotive engineering...
# ...                                                 ...
# 1159   South African Standard Time (SAST) is the tim...
# 1160   The American Airways Hangar and Administratio...
# 1161   The Air Force Reserve Command (AFRC) is a Maj...
# 1162   Leesburg is the county seat of Loudoun County...
# 1163   A cowling is the covering of a vehicle's engi...
#
#               cross_pred_entity  cross_qid  \
# 0     Conventional landing gear   Q2874355
# 1                   Herbert Lom    Q165357
# 2              MTN (TV station)   Q6718480
# 3                      Mesquite   Q3315767
# 4                     Elementis   Q5358919
# ...                         ...        ...
# 1159  Marine Science Technician  Q16203277
# 1160           Goodyear Airdock   Q3110737
# 1161        Air traffic control    Q221395
# 1162          Leesburg, Florida    Q625833
# 1163                    Cowling   Q1138219
#
#                                              cross_desc
# 0      Conventional landing gear, or tailwheel-type ...
# 1      Herbert Lom (; 11 September 1917 – 27 Septemb...
# 2      MTN is a television station licensed to serve...
# 3      Mesquite is a common name for several plants ...
# 4      Elementis plc is one of the UK's largest spec...
# ...                                                 ...
# 1159   Marine Science Technician (MST) is an enliste...
# 1160   The Goodyear Airdock is a construction and st...
# 1161   Air traffic control (ATC) is a service provid...
# 1162   Leesburg is a city in Lake County, Florida, U...
# 1163   A cowling is the covering of a vehicle's engi...
#
# [1164 rows x 11 columns]

# %%
# rename columns
data.rename(columns={"c5": "id", "c119": "sample", "c119_entity_linking":"entity_linking"}, inplace=True)

# filter data where 'id' values are in gs_samples 'id' values
gs_samples = pd.read_csv(gs_samples_path)
mask = data['id'].isin(gs_samples['id'])
data = data[mask].copy()

# convert the string representation of a list of dictionaries to actual list of dictionaries
data['entity_linking'] = data['entity_linking'].apply(ast.literal_eval)

# explode the entity_linking column
data = data.explode('entity_linking').reset_index(drop=True)

# Convert the dictionary column to a DataFrame
attributes_df = data['entity_linking'].apply(pd.Series)

# change the column type to object
attributes_df['indentifier'] = attributes_df['indentifier'].astype('Int64')
attributes_df

#attributes_df.drop(columns=[0], inplace=True)

# Concatenate with the original DataFrame (minus the dictionary column)
data = pd.concat([data.drop('entity_linking', axis=1), attributes_df], axis=1)

# rename columns
data.rename(columns={"label": 'entity', "indentifier": "qid"}, inplace=True)

# save the processed tool output to a file
output_path = os.path.join(output_dir, f"{nlp_task}__{tool_name}.csv")
data.to_csv(output_path, index=False)

data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/2K-paper/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/pmoreira/2K-paper/notebooks/explorations/nel__blink.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell://ssh-remote%2Barea-52.campus.nd.edu/home/pmoreira/2K-paper/notebooks/explorations/nel__blink.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # filter data where 'id' values are in gs_samples 'id' values
#       <a href='vscode-notebook-cell://ssh-remote%2Barea-52.campus.nd.edu/home/pmoreira/2K-paper/notebooks/explorations/nel__blink.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> gs_samples = pd.read_csv(gs_samples_path)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Barea-52.campus.nd.edu/home/pmoreira/2K-paper/notebooks/explorations/nel__blink.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> mask = data['id'].isin(gs_samples['id'])
#       <a href='vscode-notebook-cell://ssh-remote%2Barea-52.campus.nd.edu/home/pmoreira/2K-paper/notebooks/explorations/nel__blink.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> data = data[mask].copy()
#       <a href='vscode-notebook-cell://ssh-remote%2Barea-52.campus.nd.edu/home/pmoreira/2K-paper/notebooks/explorations/nel__blink.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # convert the string representation of a list of dictionaries to actual list of dictionaries
#
# File ~/2K-paper/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/2K-paper/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'id'

# %% [markdown]
# ## Gold standard NEL data

# %% [markdown]
# ### Load the processed gold standard data

# %%
# path to the gold standard file
task_gold_standard_path = f"../../gold_standard/processed/{nlp_task}.csv"

# load output from the tool to be evaluated
gs = pd.read_csv(task_gold_standard_path)

gs
# Out:
#                   id                                             sample  \
# 0    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 1    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 2    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 3    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 4    19800217031649I  AFTER TAKEOFF, ENGINE QUIT. WING FUEL TANK SUM...
# ..               ...                                                ...
# 496  19870523018729A  CANOPY CAME OPEN ON CLIMBOUT CAUSING AN UNCONT...
# 497  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 498  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 499  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 500  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
#
#              entity       qid
# 0              ACFT     11436
# 1             DITCH   2048319
# 2              TREE     10884
# 3      LOST CONTROL  29017603
# 4           TAKEOFF    854248
# ..              ...       ...
# 496     PILOT ERROR   3057459
# 497           PILOT   2095549
# 498  OIL FILLER CAP        -1
# 499             OIL     42962
# 500          ENGINE     44167
#
# [501 rows x 4 columns]

# %%
id = '19990213001379A'
print(gs['sample'][gs.id==id].unique())
print(data['sample'][data.id==id].unique())
# Out:
# ['ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CONTROL, RAN INTO A DITCH, AND STRUCK A TREE. OTHER CIRCUMSTANCES AE UNK']
# ['ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CONTROL, RAN INTO A DITCH, AND STRUCK A TREE. OTHER CIRCUMSTANCES AE UNK']

# %%
cols = ['id','entity','qid']
gs[cols][gs.id==id]
# Out:
#                 id        entity       qid
# 0  19990213001379A          ACFT     11436
# 1  19990213001379A         DITCH   2048319
# 2  19990213001379A          TREE     10884
# 3  19990213001379A  LOST CONTROL  29017603

# %%
cols = ['id','entity','qid', 'description']
data[cols][data.id==id]
# Out:
#                     id                                  entity       qid  \
# 14221  19990213001379A  United States Army Combat Fitness Test  67935434
# 14222  19990213001379A                                The Take   3989575
# 14223  19990213001379A                           OpenType Font    260180
# 14224  19990213001379A                                 Control  54935655
# 14225  19990213001379A                   Royal Australian Navy    741691
# 14226  19990213001379A                        Charlotte Brontë    127332
# 14227  19990213001379A                     Adobe After Effects     83380
#
#                                              description
# 14221   Physical fitness test for the United States Army
# 14222                                  television series
# 14223                                        file format
# 14224  2019 action-adventure video game developed by ...
# 14225  naval warfare branch of the Australian Defence...
# 14226                          English novelist and poet
# 14227   digital motion graphics and compositing software

# %% [markdown]
# ### Find partial matches
#
#
# Find partial matches between the `entity` values in your `gs` and `data` DataFrames, where the `entity` from `gs` is contained within the `entity` in `data` for the same `id`.

# %%
# Filter out rows where 'qid' is '-1'
gs= gs[gs['qid'] != -1]
gs.shape
# Out:
# (396, 4)

# %%
# Initialize an empty list to store matching records
matches = []

# Iterate through each row in the gs dataframe
for _, gs_row in gs.iterrows():
    # Filter the data dataframe for rows with the same id
    data_filtered = data[data['id'] == gs_row['id']]
    
    # Check if the gs entity is a substring of any entity in the filtered data rows
    for _, data_row in data_filtered.iterrows():
        if gs_row['entity'].lower() in data_row['entity'].lower():
            # Add the match to the matches list with qid values from both gs and data
            match = {
                'gs_id': gs_row['id'],
                'gs_entity': gs_row['entity'],
                'gs_qid': gs_row['qid'],  # qid from gs
                'data_entity': data_row['entity'],
                'data_qid': int(data_row['qid']),  # qid from data
                'data_description': data_row['description']
            }
            matches.append(match)

# Convert the matches list to a DataFrame
matches_df = pd.DataFrame(matches)

matches_df
# Out:
#                gs_id    gs_entity    gs_qid  data_entity  data_qid  \
# 0    19800217031649I      TAKEOFF    854248      Takeoff  48719890
# 1    19800217031649I       ENGINE     44167       Engine  18353587
# 2    19800217031649I         WING    161358         WING   7950776
# 3    19790720021329A   HELICOPTER     34486   HElicopTEr   5629507
# 4    19790720021329A        TREES     10884        Trees   7837713
# ..               ...          ...       ...          ...       ...
# 204  19960418007829A    DEPARTURE  21171241    Departure   1922930
# 205  19870523018729A  PILOT ERROR   3057459  pilot error   3057459
# 206  20030620012809I        PILOT   2095549        PILOT   2044212
# 207  20030620012809I          OIL     42962          Oil   7081283
# 208  20030620012809I       ENGINE     44167       Engine  18353587
#
#                                       data_description
# 0    American rapper, member of the hip hop group M...
# 1                                                 None
# 2          commercial AM radio station in Dayton, Ohio
# 3                                    album by Download
# 4                                 poem by Joyce Kilmer
# ..                                                 ...
# 204                                   album by Journey
# 205  decision, action or inaction by a pilot of an ...
# 206                      historic programming language
# 207                          episode of The Young Ones
# 208                                               None
#
# [209 rows x 6 columns]

# %%
# Count True Positives where gs_qid matches data_qid
TP = sum(matches_df['gs_qid'] == matches_df['data_qid'])

# Output the count of True Positives
print(f"True Positives: {TP}")
# Out:
# True Positives: 28
