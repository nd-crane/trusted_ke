# %% [markdown]
# # Prepare and standardize the gold standard data

# %% [markdown]
# From ``../gold_standard/raw/*.cvs`` to ``../gold_standard/procesed/*.csv``

# %% [markdown]
# ## Gold standard samples
# ---

# %%
import pandas as pd

gold_standard_path = '../gold_standard/raw/samples.csv'

# load output from the tool to be evaluated
data = pd.read_csv(gold_standard_path)

# rename columns
data.rename(columns={"c5_unique_id": "id", "c119_text": "sample"}, inplace=True)

# save the processed tool output to a file
data.to_csv('../gold_standard/processed/samples.csv', index=False)

data
# Out:
#                  id                                             sample
# 0   19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 1   19800217031649I  AFTER TAKEOFF, ENGINE QUIT. WING FUEL TANK SUM...
# 2   19790720021329A  HELICOPTER TOOK OFF WITH SLING LOAD ATTACHED. ...
# 3   19841214074599I  WHILE TAXIING LOST NOSEWHEEL STEERING AND BRAK...
# 4   19860128014289I  FORWARD CARGO DOOR OPENED AS AIRCRAFT TOOK OFF...
# ..              ...                                                ...
# 95  19880527016939A  ENGINE QUIT ON INITIAL CLIMBOUT. CRASH LANDED ...
# 96  19960418007829A  CRASHED AND BURNED. (.4)WITNESSES REPORTED THA...
# 97  19970828026989A  LOUD POP ON TAKEOFF ROLL. LOST RUDDER CONTROL....
# 98  19870523018729A  CANOPY CAME OPEN ON CLIMBOUT CAUSING AN UNCONT...
# 99  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Gold standard NEL data
#
# Code updated for Flexible GS

# %%
import math

gold_standard_path = '../gold_standard/raw/nel.csv'

# load output from the tool to be evaluated
data = pd.read_csv(gold_standard_path)

# get rid of rows with a None QID for the primary ent
#data = data[data['primary_qids'].apply(lambda x: type(x) == str)]
#data = data.reindex(range(len(data)))

# rename columns
data.rename(columns={"c5_unique_id": "id", "c119_text": "sample"}, inplace=True)
data['entity'] = range(len(data))
data['qid'] = range(len(data))

# compile primary, secondary, and tertiary entities and qids into parallel lists
prefixes = ['primary_','secondary_','tertiary_']
data['entity'] = data['entity'].apply(lambda i: [data[prefix+'ents'].iat[i] if type(data[prefix+'ents'].iat[i])==str else None for prefix in prefixes])
data['qid'] = data['qid'].apply(lambda i: [data[prefix+'qids'].iat[i] if type(data[prefix+'qids'].iat[i])==str else None for prefix in prefixes])

# Save the processed tool output to a file
data[['id','sample','entity','qid']].to_csv('../gold_standard/processed/nel.csv', index=False)
data[['id','sample','entity','qid']]
# Out:
#                   id                                             sample  \
# 0    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 1    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 2    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 3    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 4    19800217031649I  AFTER TAKEOFF, ENGINE QUIT. WING FUEL TANK SUM...
# ..               ...                                                ...
# 494  19870523018729A  CANOPY CAME OPEN ON CLIMBOUT CAUSING AN UNCONT...
# 495  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 496  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 497  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 498  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
#
#                           entity                       qid
# 0             [ACFT, None, None]      [Q11436, None, None]
# 1            [DITCH, None, None]    [Q2048319, None, None]
# 2             [TREE, None, None]      [Q10884, None, None]
# 3     [LOST CONTROL, None, None]        [None, None, None]
# 4          [TAKEOFF, None, None]     [Q854248, None, None]
# ..                           ...                       ...
# 494   [PILOT ERROR, ERROR, None]  [Q3057459, Q29485, None]
# 495          [PILOT, None, None]    [Q2095549, None, None]
# 496  [OIL FILLER CAP, CAP, None]    [None, Q6147804, None]
# 497            [OIL, None, None]      [Q42962, None, None]
# 498         [ENGINE, None, None]     [Q743004, None, None]
#
# [499 rows x 4 columns]

# %% [markdown]
# ## Gold standard RE data
#
# DNE!

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

gold_standard_path = '../gold_standard/raw/re.csv'

# load output from the tool to be evaluated
data = pd.read_csv(gold_standard_path)

# get the columns of interest
data = data[['c5_unique_id', 'c119_text', 'subject(Label), relation_type(Label), object(Label) ']]

# rename the columns
data.rename(columns={"c5_unique_id": "id", "c119_text": "sample", 'subject(Label), relation_type(Label), object(Label) ':"triple"}, inplace=True)

# Explode the 'triple' column on '\n'
data = data.assign(triple=data['triple'].str.split('\n')).explode('triple')

# Splitting the 'triple' column into 'subject', 'relation', and 'object' and their respective types
split_columns = data['triple'].str.extract('(.*) \((.*)\), (.*) \((.*)\), (.*) \((.*)\)')
data[['subject', 'subject_type', 'relation', 'relation_type', 'object', 'object_type']] = split_columns

# Show the modified DataFrame
data = data[['id', 'subject', 'subject_type', 'relation', 'relation_type', 'object', 'object_type']]

# Save the processed tool output to a file
data.to_csv('../gold_standard/processed/re.csv', index=False)

data
# Out:
#                 id                          subject            subject_type  \
# 0  19990213001379A                         Aircraft          Object/Subject
# 0  19990213001379A                         Aircraft          Object/Subject
# 0  19990213001379A                         Aircraft          Object/Subject
# 0  19990213001379A                         Aircraft          Object/Subject
# 0  19990213001379A              Other Circumstances  Contextual Information
# 1  19800217031649I                           Engine               Component
# 1  19800217031649I             Wing Fuel Tank Sumps               Component
# 1  19800217031649I             Wing Fuel Tank Sumps               Component
# 1  19800217031649I                          Drained                  Action
# 2  19790720021329A                       Helicopter           Aircraft type
# 2  19790720021329A                       Helicopter           Aircraft type
# 2  19790720021329A                            Crash                Incident
# 3  19841214074599I                          Taxiing         Phase/Operation
# 3  19841214074599I                          Taxiing         Phase/Operation
# 3  19841214074599I                         Aircraft                  Object
# 3  19841214074599I   Circuit Breaker Hydraulic Pump               Component
# 4  19860128014289I               Forward Cargo Door               Component
# 4  19860128014289I                          Objects                  Object
# 4  19860128014289I                         Aircraft                  Object
# 4  19860128014289I                              NaN                     NaN
# 5  20000215010329A          MR. TIMOTHY ALLEN WELLS                  Person
# 5  20000215010329A          MR. TIMOTHY ALLEN WELLS                  Person
# 5  20000215010329A  BELL HELICOPTER MODEL BHT-47-G5          Aircraft Model
# 6  19801116083749I                   Forced Landing                   Event
# 6  19801116083749I                              Ice               Condition
# 7  19850315007389A                            Pilot                  Person
# 7  19850315007389A                            Pilot                  Person
# 7  19850315007389A                        Altimeter               Component
# 7  19850315007389A                            Icing               Condition
# 8  20070630826079I                         Aircraft                  Object
# 8  20070630826079I                         Aircraft                  Object
# 8  20070630826079I                         Aircraft                  Object
# 8  20070630826079I                           Engine               Component
# 9  19900425011659A                             Fuel                Resource
# 9  19900425011659A                     Left Pontoon               Component
# 9  19900425011659A                     Left Pontoon               Component
# 9  19900425011659A                         Fuel Cap               Component
# 9  19900425011659A                    Fuel siphoned                incident
#
#                   relation       relation_type  \
# 0           was performing  Activity/Operation
# 0                     lost    Negative Outcome
# 0                 ran into           Collision
# 0                   struck           Collision
# 0                   status           Condition
# 1               quit after            Temporal
# 1  were not drained during    Condition/Action
# 1                condition           Condition
# 1             prevented by              Causal
# 2            took off with              Action
# 2           crashed due to              Causal
# 2                caused by              Causal
# 3                     lost    Negative Outcome
# 3                     lost    Negative Outcome
# 3                   struck           Collision
# 3                   status           Condition
# 4            opened during            Temporal
# 4         dropped out from              Action
# 4           returned after            Temporal
# 4                      NaN                 NaN
# 5                acting as                Role
# 5             was pilot of         Association
# 5         has registration           Attribute
# 6           occurred after            Temporal
# 6                 found in             Spatial
# 7        descending due to              Causal
# 7              experienced               Event
# 7                      not       Certification
# 7           was forecasted            Temporal
# 8            departed from             Spatial
# 8            entered phase            Temporal
# 8            entered phase            Temporal
# 8          started to have        State Change
# 9           ran out during              Causal
# 9         separated during               Event
# 9                landed in             Spatial
# 9              not secured               State
# 9                caused by              Causal
#
#                             object            object_type
# 0             Taxiing for Take Off     Activity/Operation
# 0                          Control   Incident Description
# 0                            Ditch        Object/Obstacle
# 0                             Tree        Object/Obstacle
# 0                          Unknown     Status/Detail Type
# 1                          Takeoff        Phase/Operation
# 1                        Preflight        Phase/Operation
# 1                           Frozen              Condition
# 1                           Frozen              Condition
# 2                       Sling Load                  Cargo
# 2             Load Wedged in Trees         Incident Cause
# 2               Improper Preflight              Condition
# 3               Nosewheel Steering              Component
# 3                           Brakes              Component
# 3                            Fence                 Object
# 3                             Open              Condition
# 4                          Takeoff        Phase/Operation
# 4               Forward Cargo Door              Component
# 4              Objects dropped out                  Event
# 4                              NaN                    NaN
# 5                 PILOT IN COMMAND                   Role
# 5  BELL HELICOPTER MODEL BHT-47-G5         Aircraft Model
# 5                           N4754R  Aircraft Registration
# 6                      Engine Quit                  State
# 6            Auxiliary Fuel System              Component
# 7                            Icing              Condition
# 7                     Lost Control                  Event
# 7                    IFR Certified          Certification
# 7                   Icing Forecast                  Event
# 8                      Ray Airport               Location
# 8                          Takeoff                  Phase
# 8                            Climb                  Phase
# 8                         Problems              Condition
# 9                     Ferry Flight              Operation
# 9                          Landing                 Action
# 9                             Pond               Location
# 9                             Fuel               Resource
# 9             Fuel Cap not Secured                  State

# %% [markdown]
# ## Gold standard NER data
#
# Un-typed NER GS:

# %%
import pandas as pd

gold_standard_path = '../gold_standard/raw/ner.csv'

# load output from the tool to be evaluated
data = pd.read_csv(gold_standard_path)


# rename columns
columns={"c5_unique_id": "id", "c119_text": "sample", "Combined":"entities"}
data.rename(columns=columns, inplace=True)

data = data[['id', 'sample', 'entities']]

# Remove spaces within entities, split by comma, then explode
data['entities'] = data['entities'].str.replace(', ', ',').str.split(',')
data = data.explode('entities').reset_index(drop=True)

# Save the processed tool output to a file
data.to_csv('../gold_standard/processed/ner.csv', index=False)
data
# Out:
#                   id                                             sample  \
# 0    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 1    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 2    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 3    19990213001379A  ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...
# 4    19800217031649I  AFTER TAKEOFF, ENGINE QUIT. WING FUEL TANK SUM...
# ..               ...                                                ...
# 501  19870523018729A  CANOPY CAME OPEN ON CLIMBOUT CAUSING AN UNCONT...
# 502  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 503  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 504  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
# 505  20030620012809I  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...
#
#            entities
# 0              ACFT
# 1             DITCH
# 2              TREE
# 3      LOST CONTROL
# 4           TAKEOFF
# ..              ...
# 501     PILOT ERROR
# 502           PILOT
# 503  OIL FILLER CAP
# 504             OIL
# 505          ENGINE
#
# [506 rows x 3 columns]

# %% [markdown]
# ### Benchmark Gold Standard NER Data

# %%
import pandas as pd
import ast

gold_standard_path = '../gold_standard/raw/ner_benchmarks_gold.csv'

# load output from the tool to be evaluated
original_data = pd.read_csv(gold_standard_path, skiprows=8, header=0)
original_data.loc[17, 'ace_ents'] = '["GROUND STAND","GROUND STAND BAGGAGE CART WITH INOPERATIVE BRAKES","AIRCRAFT","FUSELAGE"]'
original_data.loc[44, 'ace_labels'] = '["VEHICLE","PER","PER"]'

for bench in ['conll','ace','on']:

    columns={"c5_unique_id": "id", "c119_text": "sample", bench+"_ents":"entities",bench+"_labels":"labels"}
    data = original_data.rename(columns=columns)
    
    data = data[['id', 'sample', 'entities','labels']]
    
    # Get lists of entities and labels from strings
    data['entities'] = data['entities'].apply(lambda x: [] if type(x) != str else ast.literal_eval(x))
    data['labels'] = data['labels'].apply(lambda x: [] if type(x) != str else ast.literal_eval(x))
    
    # Explode
    data = pd.concat([data[['id','sample','entities']].explode('entities').reset_index(drop=True), data['labels'].explode('labels').reset_index(drop=True)], axis=1)

    #save
    data.to_csv(f'../gold_standard/processed/ner_{bench}.csv', index=False)

# %%
# Make ACE-2005 GS with restricted set of labels used by NLTK

gold_standard_path = '../gold_standard/raw/ner_benchmarks_gold.csv'

# load output from the tool to be evaluated
original_data = pd.read_csv(gold_standard_path, skiprows=8, header=0)
original_data.loc[17, 'ace_ents'] = '["GROUND STAND","GROUND STAND BAGGAGE CART WITH INOPERATIVE BRAKES","AIRCRAFT","FUSELAGE"]'
original_data.loc[44, 'ace_labels'] = '["VEHICLE","PER","PER"]'

bench = 'ace'

columns={"c5_unique_id": "id", "c119_text": "sample", bench+"_ents":"entities",bench+"_labels":"labels"}
data = original_data.rename(columns=columns)

data = data[['id', 'sample', 'entities','labels']]

# Get lists of entities and labels from strings
data['entities'] = data['entities'].apply(lambda x: [] if type(x) != str else ast.literal_eval(x))
data['labels'] = data['labels'].apply(lambda x: [] if type(x) != str else ast.literal_eval(x))

# Remove "VEHICLE" entities and labels
for i in range(len(data)):
    while "VEHICLE" in data['labels'].iat[i]:
        vehicle_idx = data['labels'].iat[i].index("VEHICLE")
        data['entities'].iat[i] = data['entities'].iat[i][:vehicle_idx] + data['entities'].iat[i][vehicle_idx+1:]
        data['labels'].iat[i] = data['labels'].iat[i][:vehicle_idx] + data['labels'].iat[i][vehicle_idx+1:]

# Explode
data = pd.concat([data[['id','sample','entities']].explode('entities').reset_index(drop=True), data['labels'].explode('labels').reset_index(drop=True)], axis=1)

#save
data.to_csv(f'../gold_standard/processed/ner_ace_nltk.csv', index=False)

# %%
import csv


input_file_path = '../gold_standard/raw/ner_own_types.csv'
output_file_path = '../gold_standard/processed/ner_own_types.csv'

# Read the CSV file
with open(input_file_path, mode='r', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    data = [row for row in reader]

# Process the data and write to a new CSV file
with open(output_file_path, mode='w', newline='') as csvfile:
    fieldnames = ['id', 'sample', 'entities', 'types']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for row in data:
        c5_unique_id = row['id']
        c119_text = row['sample']
        
        gs_list = eval(row['entities'])
        gs_type_list = eval(row['types'])
        
        for gs, gs_type in zip(gs_list, gs_type_list):
            writer.writerow({
                'id': c5_unique_id,
                'sample': c119_text,
                'entities': gs,
                'types': gs_type
            })

print(f"Processed data has been written to {output_file_path}")
# Out:
# Processed data has been written to ../gold_standard/processed/ner_own_types.csv
