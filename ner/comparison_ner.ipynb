# %%
import pandas as pd

sample = pd.read_csv("../data/sampling/FAA_sample_100.csv")

flair = pd.read_csv("../data/results/flair/flair_ner.csv")
spacy = pd.read_csv("../data/results/spacy_entityrecognizer/spacy_ner.csv")
stanza = pd.read_csv("../data/results/stanza/stanza_ner.csv")

dfs = {"flair":flair, "spacy":spacy, "stanza":stanza}

out_dict = {'index':[], 'c5_unique_id':[], 'c119_text':[], 'flair_entities':[], 'flair_labels':[],\
            'spacy_entities':[], 'spacy_labels':[],\
            'stanza_entities':[], 'stanza_labels':[]}

# %%
out_dict = {'index':[], 'c5_unique_id':[], 'c119_text':[], 'flair_entities':[], 'flair_labels':[],\
            'spacy_entities':[], 'spacy_labels':[],\
            'stanza_entities':[], 'stanza_labels':[]}

for index in range(len(sample)):
    for tool, df in dfs.items():
        results = df[df["index"] == sample['Unnamed: 0'][index]]
        for iresult in range(len(results)):
            result = results.iloc[iresult]
            out_dict["index"].append(sample['Unnamed: 0'][index])
            out_dict["c5_unique_id"].append(result["c5_unique_id"])
            out_dict["c119_text"].append(result["c119_text"])
            
            ent_results = {key : "--" for key in dfs.keys()}
            label_results = {key : "--" for key in dfs.keys()}
            ent_results[tool] = result["entities"]
            label_results[tool] = result["labels"]
            for key in dfs.keys():
                out_dict[f"{key}_entities"].append(ent_results[key])
                out_dict[f"{key}_labels"].append(label_results[key])

# %%
pd.DataFrame(out_dict)
# Out:
#      index     c5_unique_id  \
# 0     2318  19990213001379A
# 1     2318  19990213001379A
# 2      817  19841214074599I
# 3      817  19841214074599I
# 4      817  19841214074599I
# ..     ...              ...
# 193   2045  19970828026989A
# 194   2045  19970828026989A
# 195   2045  19970828026989A
# 196   1210  19870523018729A
# 197   2488  20030620012809I
#
#                                              c119_text flair_entities  \
# 0    ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...           ACFT
# 1    ACFT WAS TAXIING FOR TAKE OFF WHEN IT LOST CON...             --
# 2    WHILE TAXIING LOST NOSEWHEEL STEERING AND BRAK...             --
# 3    WHILE TAXIING LOST NOSEWHEEL STEERING AND BRAK...             --
# 4    WHILE TAXIING LOST NOSEWHEEL STEERING AND BRAK...             --
# ..                                                 ...            ...
# 193  LOUD POP ON TAKEOFF ROLL. LOST RUDDER CONTROL....             --
# 194  LOUD POP ON TAKEOFF ROLL. LOST RUDDER CONTROL....             --
# 195  LOUD POP ON TAKEOFF ROLL. LOST RUDDER CONTROL....             --
# 196  CANOPY CAME OPEN ON CLIMBOUT CAUSING AN UNCONT...             --
# 197  (-23) PILOT FAILED TO ASSURE THE OIL FILLER CA...             --
#
#                                           flair_labels        spacy_entities  \
# 0    [{'value': 'ORG', 'confidence': 0.645385682582...                    --
# 1                                                   --  CIRCUMSTANCES AE UNK
# 2                                                   --                     2
# 3                                                   --       CIRCUIT BREAKER
# 4                                                   --                  PUMP
# ..                                                 ...                   ...
# 193                                                 --               CONTROL
# 194                                                 --                EXITED
# 195                                                 --             TAILWHEEL
# 196                                                 --                CANOPY
# 197                                                 --                ENGINE
#
#     spacy_labels stanza_entities stanza_labels
# 0             --              --            --
# 1            ORG              --            --
# 2       CARDINAL              --            --
# 3         PERSON              --            --
# 4            ORG              --            --
# ..           ...             ...           ...
# 193          ORG              --            --
# 194          ORG              --            --
# 195          ORG              --            --
# 196          ORG              --            --
# 197          ORG              --            --
#
# [198 rows x 9 columns]

# %%
pd.DataFrame(out_dict).to_csv("comparison_ner.csv", index=False)
